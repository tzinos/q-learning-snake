# %% [markdown]
# # Setup

# %%
import itertools
import json

sqs = [''.join(s) for s in list(itertools.product(*[['0','1']] * 4))]
widths = ['0','1','NA']
heights = ['2','3','NA']

states = {}
for i in widths:
	for j in heights:
		for k in sqs:
			states[str((i,j,k))] = [0,0,0,0]

with open("qvalues.json", "w") as f:
	json.dump(states, f)

# %% [markdown]
# # Learner

# %%
import random
import json

import dataclasses

@dataclasses.dataclass
class GameState:
    distance: tuple
    position: tuple
    surroundings: str
    food: tuple


class Learner(object):
    def __init__(self, display_width, display_height, block_size):
        # Game parameters
        self.display_width = display_width
        self.display_height = display_height
        self.block_size = block_size

        # Learning parameters
        self.epsilon = 0.1
        self.lr = 0.7
        self.discount = .5

        # State/Action history
        self.qvalues = self.LoadQvalues()
        self.history = []

        # Action space
        self.actions = {
            0:'left',
            1:'right',
            2:'up',
            3:'down'
        }

    def Reset(self):
        self.history = []

    def LoadQvalues(self, path="qvalues.json"):
        with open(path, "r") as f:
            qvalues = json.load(f)
        return qvalues

    def SaveQvalues(self, path="qvalues.json"):
        with open(path, "w") as f:
            json.dump(self.qvalues, f)
            
    def act(self, snake, food):
        state = self._GetState(snake, food)

        # Epsilon greedy
        rand = random.uniform(0,1)
        if rand < self.epsilon:
            action_key = random.choices(list(self.actions.keys()))[0]
        else:
            state_scores = self.qvalues[self._GetStateStr(state)]
            action_key = state_scores.index(max(state_scores))
        action_val = self.actions[action_key]
        
        # Remember the actions it took at each state
        self.history.append({
            'state': state,
            'action': action_key
            })
        return action_val
    
    def UpdateQValues(self, reason):
        history = self.history[::-1]
        for i, h in enumerate(history[:-1]):
            if reason: # Snake Died -> Negative reward
                sN = history[0]['state']
                aN = history[0]['action']
                state_str = self._GetStateStr(sN)
                reward = -1
                self.qvalues[state_str][aN] = (1-self.lr) * self.qvalues[state_str][aN] + self.lr * reward # Bellman equation - there is no future state since game is over
                reason = None
            else:
                s1 = h['state'] # current state
                s0 = history[i+1]['state'] # previous state
                a0 = history[i+1]['action'] # action taken at previous state
                
                x1 = s0.distance[0] # x distance at current state
                y1 = s0.distance[1] # y distance at current state
    
                x2 = s1.distance[0] # x distance at previous state
                y2 = s1.distance[1] # y distance at previous state
                
                if s0.food != s1.food: # Snake ate a food, positive reward
                    reward = 1
                elif (abs(x1) > abs(x2) or abs(y1) > abs(y2)): # Snake is closer to the food, positive reward
                    reward = 1
                else:
                    reward = -1 # Snake is further from the food, negative reward
                    
                state_str = self._GetStateStr(s0)
                new_state_str = self._GetStateStr(s1)
                self.qvalues[state_str][a0] = (1-self.lr) * (self.qvalues[state_str][a0]) + self.lr * (reward + self.discount*max(self.qvalues[new_state_str])) # Bellman equation


    def _GetState(self, snake, food):
        snake_head = snake[-1]
        dist_x = food[0] - snake_head[0]
        dist_y = food[1] - snake_head[1]

        if dist_x > 0:
            pos_x = '1' # Food is to the right of the snake
        elif dist_x < 0:
            pos_x = '0' # Food is to the left of the snake
        else:
            pos_x = 'NA' # Food and snake are on the same X file

        if dist_y > 0:
            pos_y = '3' # Food is below snake
        elif dist_y < 0:
            pos_y = '2' # Food is above snake
        else:
            pos_y = 'NA' # Food and snake are on the same Y file

        sqs = [
            (snake_head[0]-self.block_size, snake_head[1]),   
            (snake_head[0]+self.block_size, snake_head[1]),         
            (snake_head[0],                  snake_head[1]-self.block_size),
            (snake_head[0],                  snake_head[1]+self.block_size),
        ]
        
        surrounding_list = []
        for sq in sqs:
            if sq[0] < 0 or sq[1] < 0: # off screen left or top
                surrounding_list.append('1')
            elif sq[0] >= self.display_width or sq[1] >= self.display_height: # off screen right or bottom
                surrounding_list.append('1')
            elif sq in snake[:-1]: # part of tail
                surrounding_list.append('1')
            else:
                surrounding_list.append('0')
        surroundings = ''.join(surrounding_list)

        return GameState((dist_x, dist_y), (pos_x, pos_y), surroundings, food)

    def _GetStateStr(self, state):
        return str((state.position[0],state.position[1],state.surroundings))

# %%
#%%
import pygame
import random
#import Learner

pygame.init()

#%% CONSTANTS
YELLOW = (255, 255, 102)
BLACK = (0, 0, 0)
GREEN = (0, 255, 0)
BLUE = (50, 153, 213)

BLOCK_SIZE = 10 
DIS_WIDTH = 600
DIS_HEIGHT = 400

QVALUES_N = 100
FRAMESPEED = 50000

#%% Game 

def GameLoop():
    global dis
    
    dis = pygame.display.set_mode((DIS_WIDTH, DIS_HEIGHT))
    pygame.display.set_caption('Snake')
    clock = pygame.time.Clock()

    # Starting position of snake
    x1 = DIS_WIDTH / 2
    y1 = DIS_HEIGHT / 2
    x1_change = 0
    y1_change = 0
    snake_list = [(x1,y1)]
    length_of_snake = 1

    # Create first food
    foodx = round(random.randrange(0, DIS_WIDTH - BLOCK_SIZE) / 10.0) * 10.0
    foody = round(random.randrange(0, DIS_HEIGHT - BLOCK_SIZE) / 10.0) * 10.0

    dead = False
    reason = None
    while not dead:
        # Get action from agent
        action = learner.act(snake_list, (foodx,foody))
        if action == "left":
            x1_change = -BLOCK_SIZE
            y1_change = 0
        elif action == "right":
            x1_change = BLOCK_SIZE
            y1_change = 0
        elif action == "up":
            y1_change = -BLOCK_SIZE
            x1_change = 0
        elif action == "down":
            y1_change = BLOCK_SIZE
            x1_change = 0

        # Move snake
        x1 += x1_change
        y1 += y1_change
        snake_head = (x1,y1)
        snake_list.append(snake_head)

        # Check if snake is off screen
        if x1 >= DIS_WIDTH or x1 < 0 or y1 >= DIS_HEIGHT or y1 < 0:
            reason = 'Screen'
            dead = True

        # Check if snake hit tail
        if snake_head in snake_list[:-1]:
            reason = 'Tail'
            dead = True

        # Check if snake ate food
        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, DIS_WIDTH - BLOCK_SIZE) / 10.0) * 10.0
            foody = round(random.randrange(0, DIS_HEIGHT - BLOCK_SIZE) / 10.0) * 10.0
            length_of_snake += 1

        # Delete the last cell since we just added a head for moving, unless we ate a food
        if len(snake_list) > length_of_snake:
            del snake_list[0]

        # Draw food, snake and update score
        dis.fill(BLUE)
        DrawFood(foodx, foody)
        DrawSnake(snake_list)
        DrawScore(length_of_snake - 1)
        pygame.display.update()

        # Update Q Table
        learner.UpdateQValues(reason)
        
        # Next Frame
        clock.tick(FRAMESPEED)

    return length_of_snake - 1, reason

def DrawFood(foodx, foody):
    pygame.draw.rect(dis, GREEN, [foodx, foody, BLOCK_SIZE, BLOCK_SIZE])   

def DrawScore(score):
    font = pygame.font.SysFont("comicsansms", 35)
    value = font.render(f"Score: {score}", True, YELLOW)
    dis.blit(value, [0, 0])

def DrawSnake(snake_list):
    for x in snake_list:
        pygame.draw.rect(dis, BLACK, [x[0], x[1], BLOCK_SIZE, BLOCK_SIZE])



#%%
game_count = 1

learner = Learner(DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE)

while True:
    learner.Reset()
    if game_count > 100:
        learner.epsilon = 0
    else:
        learner.epsilon = .1
    score, reason = GameLoop()
    print(f"Games: {game_count}; Score: {score}; Reason: {reason}") # Output results of each game to console to monitor as agent is training
    game_count += 1
    if game_count % QVALUES_N == 0: # Save qvalues every qvalue_dump_n games
        print("Save Qvals")
        learner.SaveQvalues()
# Out:
# pygame 2.5.2 (SDL 2.28.2, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# error: XDG_RUNTIME_DIR not set in the environment.
# Games: 1; Score: 1; Reason: Tail
# Games: 2; Score: 1; Reason: Tail
# Games: 3; Score: 1; Reason: Tail
# Games: 4; Score: 1; Reason: Tail
# Games: 5; Score: 1; Reason: Tail
# Games: 6; Score: 1; Reason: Tail
# Games: 7; Score: 1; Reason: Tail
# Games: 8; Score: 1; Reason: Tail
# Games: 9; Score: 1; Reason: Tail
# Games: 10; Score: 1; Reason: Tail
# Games: 11; Score: 1; Reason: Tail
# Games: 12; Score: 1; Reason: Tail
# Games: 13; Score: 2; Reason: Tail
# Games: 14; Score: 1; Reason: Tail
# Games: 15; Score: 1; Reason: Tail
# Games: 16; Score: 1; Reason: Tail
# Games: 17; Score: 1; Reason: Tail
# Games: 18; Score: 1; Reason: Tail
# Games: 19; Score: 3; Reason: Tail
# Games: 20; Score: 2; Reason: Tail
# Games: 21; Score: 2; Reason: Tail
# Games: 22; Score: 2; Reason: Tail
# Games: 23; Score: 2; Reason: Tail
# Games: 24; Score: 3; Reason: Tail
# Games: 25; Score: 1; Reason: Tail
# Games: 26; Score: 1; Reason: Tail
# Games: 27; Score: 1; Reason: Tail
# Games: 28; Score: 1; Reason: Tail
# Games: 29; Score: 1; Reason: Tail
# Games: 30; Score: 1; Reason: Tail
# Games: 31; Score: 1; Reason: Tail
# Games: 32; Score: 1; Reason: Tail
# Games: 33; Score: 4; Reason: Tail
# Games: 34; Score: 1; Reason: Tail
# Games: 35; Score: 3; Reason: Tail
# Games: 36; Score: 1; Reason: Tail
# Games: 37; Score: 2; Reason: Tail
# Games: 38; Score: 1; Reason: Tail
# Games: 39; Score: 1; Reason: Tail
# Games: 40; Score: 1; Reason: Tail
# Games: 41; Score: 1; Reason: Tail
# Games: 42; Score: 1; Reason: Tail
# Games: 43; Score: 1; Reason: Tail
# Games: 44; Score: 1; Reason: Tail
# Games: 45; Score: 2; Reason: Tail
# Games: 46; Score: 2; Reason: Tail
# Games: 47; Score: 1; Reason: Tail
# Games: 48; Score: 1; Reason: Tail
# Games: 49; Score: 1; Reason: Tail
# Games: 50; Score: 2; Reason: Tail
# Games: 51; Score: 2; Reason: Tail
# Games: 52; Score: 1; Reason: Tail
# Games: 53; Score: 1; Reason: Tail
# Games: 54; Score: 2; Reason: Tail
# Games: 55; Score: 1; Reason: Tail
# Games: 56; Score: 1; Reason: Tail
# Games: 57; Score: 3; Reason: Tail
# Games: 58; Score: 1; Reason: Tail
# Games: 59; Score: 1; Reason: Tail
# Games: 60; Score: 3; Reason: Tail
# Games: 61; Score: 2; Reason: Tail
# Games: 62; Score: 1; Reason: Tail
# Games: 63; Score: 1; Reason: Tail
# Games: 64; Score: 1; Reason: Tail
# Games: 65; Score: 1; Reason: Tail
# Games: 66; Score: 4; Reason: Tail
# Games: 67; Score: 2; Reason: Tail
# Games: 68; Score: 1; Reason: Tail
# Games: 69; Score: 1; Reason: Tail
# Games: 70; Score: 0; Reason: Screen
# Games: 71; Score: 1; Reason: Tail
# Games: 72; Score: 1; Reason: Tail
# Games: 73; Score: 1; Reason: Tail
# Games: 74; Score: 1; Reason: Tail
# Games: 75; Score: 1; Reason: Tail
# Games: 76; Score: 1; Reason: Tail
# Games: 77; Score: 1; Reason: Tail
# Games: 78; Score: 2; Reason: Tail
# Games: 79; Score: 1; Reason: Tail
# Games: 80; Score: 1; Reason: Tail
# Games: 81; Score: 3; Reason: Tail
# Games: 82; Score: 1; Reason: Tail
# Games: 83; Score: 1; Reason: Screen
# Games: 84; Score: 2; Reason: Screen
# Games: 85; Score: 1; Reason: Tail
# Games: 86; Score: 1; Reason: Tail
# Games: 87; Score: 1; Reason: Tail
# Games: 88; Score: 5; Reason: Tail
# Games: 89; Score: 2; Reason: Tail
# Games: 90; Score: 1; Reason: Tail
# Games: 91; Score: 1; Reason: Tail
# Games: 92; Score: 1; Reason: Tail
# Games: 93; Score: 2; Reason: Tail
# Games: 94; Score: 1; Reason: Tail
# Games: 95; Score: 3; Reason: Tail
# Games: 96; Score: 2; Reason: Tail
# Games: 97; Score: 1; Reason: Tail
# Games: 98; Score: 4; Reason: Tail
# Games: 99; Score: 1; Reason: Tail
# Save Qvals
# Games: 100; Score: 1; Reason: Tail
# Games: 101; Score: 14; Reason: Tail
# Games: 102; Score: 18; Reason: Tail
# Games: 103; Score: 6; Reason: Tail
# Games: 104; Score: 11; Reason: Tail
# Games: 105; Score: 22; Reason: Screen
# Games: 106; Score: 4; Reason: Tail
# Games: 107; Score: 24; Reason: Tail
# Games: 108; Score: 37; Reason: Tail
# Games: 109; Score: 7; Reason: Tail
# Games: 110; Score: 19; Reason: Tail
# Games: 111; Score: 1; Reason: Screen
# Games: 112; Score: 29; Reason: Tail
# Games: 113; Score: 13; Reason: Tail
# Games: 114; Score: 7; Reason: Tail
# Games: 115; Score: 16; Reason: Tail
# Games: 116; Score: 11; Reason: Tail
# Games: 117; Score: 30; Reason: Tail
# Games: 118; Score: 5; Reason: Tail
# Games: 119; Score: 3; Reason: Tail
# Games: 120; Score: 3; Reason: Tail
# Games: 121; Score: 10; Reason: Tail
# Games: 122; Score: 15; Reason: Tail
# Games: 123; Score: 18; Reason: Tail
# Games: 124; Score: 2; Reason: Tail
# Games: 125; Score: 4; Reason: Tail
# Games: 126; Score: 35; Reason: Tail
# Games: 127; Score: 22; Reason: Screen
# Games: 128; Score: 13; Reason: Tail
# Games: 129; Score: 11; Reason: Tail
# Games: 130; Score: 4; Reason: Screen
# Games: 131; Score: 13; Reason: Tail
# Games: 132; Score: 40; Reason: Tail
# Games: 133; Score: 12; Reason: Tail
# Games: 134; Score: 32; Reason: Tail
# Games: 135; Score: 31; Reason: Tail
# Games: 136; Score: 20; Reason: Tail
# Games: 137; Score: 27; Reason: Tail
# Games: 138; Score: 16; Reason: Tail
# Games: 139; Score: 8; Reason: Tail
# Games: 140; Score: 47; Reason: Tail
# Games: 141; Score: 19; Reason: Tail
# Games: 142; Score: 31; Reason: Tail
# Games: 143; Score: 31; Reason: Tail
# Games: 144; Score: 31; Reason: Tail
# Games: 145; Score: 37; Reason: Tail
# Games: 146; Score: 35; Reason: Tail
